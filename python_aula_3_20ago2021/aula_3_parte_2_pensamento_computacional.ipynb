# %%
arquivo = open("GMT20210806-222707_Recording.txt")
for linha in arquivo:
  print(linha.strip().split("\t")) ## contra barra t por causa do tab
# Out:
# ['00:01:36', 'Jamile Santana:', 'Boa noite!']
# ['00:05:23', 'Talita Burbulhan:', 'oi pessoal! boa noite :D']
# ['00:05:39', 'Vinícius Marques:', 'Boa noite, pessoal!!']
# ['00:06:14', 'Renan Cavalcante:', 'Boa!']
# ['00:06:51', 'Alessandro Feitosa Jr:', 'Uma dica para o Slack para achar todos os canais: passar o mouse por cima do menu "Canais" e depois cliquem em "Explorar canais", ali vão aparecer todos']
# ['00:08:29', 'Natalia:', 'Dentro do canal, é só ir em “settings” (configurações) e trocar para canal privado']
# ['00:11:24', 'Luiza Ferraz:', 'tá falhando só pra mim?']
# ['00:11:25', 'Natalia:', 'Em alguns momentos corta o som pra mim, é só pra mim?']
# ['00:11:34', 'Kaluan Bernardo:', 'Aqui ta bom!']
# ['00:11:45', 'Renan Cavalcante:', 'Aqui deu uma cortada também. Umas duas vezes.']
# ['00:11:52', 'Carina Dourado:', 'Pra mim falhou rapidinho e voltou']
# ['00:11:54', 'Kelly Pavan:', 'Aqui travou um pouquinho, também. Mas já está normal']
# ...

# %%
arquivo = open("GMT20210806-222707_Recording.txt")
for linha in arquivo:
  partes = linha.strip().split("\t") # lista de strings contendo hora, user e mensagem
  if len(partes) == 3:
    print(partes[1])
# Out:
# Jamile Santana:
# Talita Burbulhan:
# Vinícius Marques:
# Renan Cavalcante:
# Alessandro Feitosa Jr:
# Natalia:
# Luiza Ferraz:
# Natalia:
# Kaluan Bernardo:
# Renan Cavalcante:
# Carina Dourado:
# Kelly Pavan:
# layane.serrano:
# layane.serrano:
# Luiza Ferraz:
# gabriela caesar:
# Natalia:
# Érika Yukari:
# layane.serrano:
# Érika Yukari:
# Larissa Sayuri:
# Jamile Santana:
# gabriela caesar:
# gabriela caesar:
# gabriela caesar:
# Amanda Audi:
# Érika Yukari:
# Érika Yukari:
# Amanda Audi:
# Érika Yukari:
# Érika Yukari:
# Talita Burbulhan:
# Tiago:
# Kaluan Bernardo:
# Luiza Ferraz:
# Vinícius Marques:
# Érika Yukari:
# gabriela caesar:
# Ingridy Silva:
# Jamile Santana:
# Natalia:
# Kelly Pavan:
# Ingridy Silva:
# Vinícius Marques:
# Natalia:
# Talita Burbulhan:
# Érika Yukari:
# Érika Yukari:
# Érika Yukari:
# Natalia:
# Luiza Ferraz:
# Kaluan Bernardo:
# Bianca Muniz:
# Ingridy Silva:
# Karen Couto:
# Tode:
# Kelly Pavan:
# Host Insper:
# gabriela caesar:
# Natalia:
# ...

# %%
notas = [1, 2, 3, 4, 5, 6]
print(notas[0]) # primeiro item
print(notas[1]) # segundo item
print(notas[len(notas) - 1]) # tamanho da lista menos 1; comeca no zero
print(notas[-1]) # ultimo item
print(notas[-2]) # penultimo item
# Out:
# 1
# 2
# 6
# 6
# 5

# %%
arquivo = open("brasil.csv")

for i in arquivo:
  print(i)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# PR,Porto Vitória,4020,213.01
#
# PR,Prado Ferreira,3434,153.4
#
# PR,Pranchita,5628,225.84
#
# PR,Presidente Castelo Branco,4784,155.73
#
# PR,Primeiro de Maio,10832,414.44
#
# PR,Prudentópolis,48792,2308.5
#
# PR,Quarto Centenário,4856,321.88
#
# PR,Quatiguá,7045,112.69
#
# PR,Quatro Barras,19851,180.47
#
# PR,Quatro Pontes,3803,114.39
#
# PR,Quedas do Iguaçu,30605,821.5
#
# PR,Querência do Norte,11729,914.76
#
# PR,Quinta do Sol,5088,326.18
#
# PR,Quitandinha,17089,447.02
#
# PR,Ramilândia,4134,237.2
#
# PR,Rancho Alegre,3955,167.65
#
# PR,Rancho Alegre d`Oeste,2847,241.39
#
# PR,Realeza,16338,353.42
#
# PR,Rebouças,14176,481.84
#
# PR,Renascença,6812,425.27
#
# PR,Reserva,25172,1635.52
#
# PR,Reserva do Iguaçu,7307,834.23
#
# PR,Ribeirão Claro,10678,629.22
#
# PR,Ribeirão do Pinhal,13524,374.73
#
# PR,Rio Azul,14093,629.75
#
# PR,Rio Bom,3334,177.84
#
# PR,Rio Bonito do Iguaçu,13661,746.12
#
# ...

# %%
import csv 
arquivo = open("brasil.csv")
for i in csv.DictReader(arquivo):
  print(i)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# OrderedDict([('estado', 'BA'), ('municipio', 'Sapeaçu'), ('habitantes', '16585'), ('area', '117.21')])
# OrderedDict([('estado', 'BA'), ('municipio', 'Sátiro Dias'), ('habitantes', '18964'), ('area', '1010.05')])
# OrderedDict([('estado', 'BA'), ('municipio', 'Saubara'), ('habitantes', '11201'), ('area', '163.5')])
# OrderedDict([('estado', 'BA'), ('municipio', 'Saúde'), ('habitantes', '11845'), ('area', '504.31')])
# OrderedDict([('estado', 'BA'), ('municipio', 'Seabra'), ('habitantes', '41798'), ('area', '2517.29')])
# OrderedDict([('estado', 'BA'), ('municipio', 'Sebastião Laranjeiras'), ('habitantes', '10371'), ('area', '1948.61')])
# OrderedDict([('estado', 'BA'), ('municipio', 'Senhor do Bonfim'), ('habitantes', '74419'), ('area', '827.49')])
# OrderedDict([('estado', 'BA'), ('municipio', 'Sento Sé'), ('habitantes', '37425'), ('area', '12698.71')])
# ...

# %%
import csv 
arquivo = open("brasil.csv")
for i in csv.DictReader(arquivo):
  print(f"{i['municipio']}/{i['estado']} tem {i['habitantes']} habitantes")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Sapeaçu/BA tem 16585 habitantes
# Sátiro Dias/BA tem 18964 habitantes
# Saubara/BA tem 11201 habitantes
# Saúde/BA tem 11845 habitantes
# Seabra/BA tem 41798 habitantes
# Sebastião Laranjeiras/BA tem 10371 habitantes
# Senhor do Bonfim/BA tem 74419 habitantes
# Sento Sé/BA tem 37425 habitantes
# Serra do Ramalho/BA tem 31638 habitantes
# Serra Dourada/BA tem 18112 habitantes
# Serra Preta/BA tem 15401 habitantes
# Serrinha/BA tem 76762 habitantes
# Serrolândia/BA tem 12344 habitantes
# Simões Filho/BA tem 118047 habitantes
# Sítio do Mato/BA tem 12050 habitantes
# Sítio do Quinto/BA tem 12592 habitantes
# Sobradinho/BA tem 22000 habitantes
# Souto Soares/BA tem 15899 habitantes
# Tabocas do Brejo Velho/BA tem 11431 habitantes
# Tanhaçu/BA tem 20013 habitantes
# Tanque Novo/BA tem 16128 habitantes
# Tanquinho/BA tem 8008 habitantes
# Taperoá/BA tem 18748 habitantes
# Tapiramutá/BA tem 16516 habitantes
# ...
